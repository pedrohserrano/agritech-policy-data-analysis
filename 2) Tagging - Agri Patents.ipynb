# %% [markdown]
# ## Climate Change Dataset of Patents

# %% [markdown]
# ### new keywords:
# Agriculture: (based on keywords used in the patent classification)
# 'cultivation', 'forestry', 'animal husbandry', 'hunting', 'fishing', 'planting', 'sowing', 'fertisiling', 'harvesting', 'mowing','aviculture', 'apiculture', 'pisciculture', 'sowing', 'planting', 'manuring', 'harvesting'

# %%
from flashtext import KeywordProcessor
import time
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

terms = ['agriculture','agricultural','agritech','agtech','agronomy','farming','gardening','agronomics','agrology','horticulture','agribusiness','cultivation', 'forestry', 'animal husbandry', 'hunting', 'fishing', 'planting', 'sowing', 'fertisiling', 'harvesting', 'mowing','aviculture', 'apiculture', 'pisciculture', 'sowing', 'planting', 'manuring', 'harvesting']
print('terms to use: {}'.format(len(terms)))
data_patents = pd.read_excel('datasets/patents_ccm_04082020.xlsx') # ADJUST THE NAME OF THE FILE TO THE NEWEST FILE!!!
data_patents = data_patents[data_patents['count_matches'] > 0]
data_patents.head(4)
# Out:
# terms to use: 28
#    Unnamed: 0       id     type   number country        date  \
# 0     1823250  5528907  utility  5528907      US  1996-06-25
# 1     6007196  9694312  utility  9694312      US  2017-07-04
# 2     2870761  6584802  utility  6584802      US  2003-07-01
# 3     5212834  8894753  utility  8894753      US  2014-11-25
#
#                                             abstract  \
# 0   A new METHOD AND APPARATUS FOR AUTOMATICALLY ...
# 1  The present invention relates to a carbon diox...
# 2  A cooling apparatus and method that employs ca...
# 3  Disclosed is a carbon dioxide capture system w...
#
#                                                title kind  num_claims  \
# 0  Method and apparatus for automatically produci...    A           2
# 1                   Carbon dioxide capture apparatus   B2          10
# 2         Cooling apparatus employing carbon dioxide   B1           7
# 3                     Carbon dioxide capture systems   B2          17
#
# ...

# %% [markdown]
# ---
# ## Tagging CCM Patents related to Agriculture

# %%
def extract(vec, dictionary, info=False):
    matrix = []
    for line in vec:
        matrix.append(dictionary.extract_keywords(str(line), span_info=info))
    return matrix

# %%
terms_dict = KeywordProcessor()
terms_dict.add_keywords_from_list(terms)
terms_extracted = extract(data_patents.abstract, terms_dict)
rows = [list(set(i)) if len(i)>0 else '' for i in terms_extracted]
data_patents['matches'] = [str(i).replace('[', '').replace(']', '') for i in rows]
data_patents['count_matches'] = [len(i) for i in terms_extracted]

# %% [markdown]
# ---
# ## Dummy for year as from 2004

# %%
#  extracting the year from the date column
data_patents['First_year']=data_patents['date'].str.slice(stop=4)

# change year to numeric column
data_patents["First_year"] = pd.to_numeric( data_patents["First_year"],downcast='integer')

# %%
# creating dummy for all laws passed starting with the last big join of countries in 2004
After_2004= []
for i in data_patents.First_year:
    year =  1 if i >2003 else 0
    After_2004.append(year)

# adding the dummy to the original dataset
data_patents['After_2004']=After_2004
data_patents.After_2004.sum()
# Out:
# 8377

# %% [markdown]
# ---
# ## Save as Excel file

# %%
data_patents.sort_values('count_matches', ascending=False).to_excel('datasets/patents_AGRI.xlsx')
data_patents.head()
# Out:
#    Unnamed: 0       id     type   number country        date  \
# 0     1823250  5528907  utility  5528907      US  1996-06-25
# 1     6007196  9694312  utility  9694312      US  2017-07-04
# 2     2870761  6584802  utility  6584802      US  2003-07-01
# 3     5212834  8894753  utility  8894753      US  2014-11-25
# 4     1558112  5261490  utility  5261490      US  1993-11-16
#
#                                             abstract  \
# 0   A new METHOD AND APPARATUS FOR AUTOMATICALLY ...
# 1  The present invention relates to a carbon diox...
# 2  A cooling apparatus and method that employs ca...
# 3  Disclosed is a carbon dioxide capture system w...
# 4   A method for dumping carbon dioxide gas into ...
#
#                                                title kind  num_claims  \
# 0  Method and apparatus for automatically produci...    A           2
# 1                   Carbon dioxide capture apparatus   B2          10
# ...
